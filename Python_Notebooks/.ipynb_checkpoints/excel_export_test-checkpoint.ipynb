# %%
import numpy as np
import pandas as pd
import xlrd, xlwt
import xlsxwriter

path = 'C:\\Users\\oswald.ramirez\\Documents\\SQL Scripts\\169_MarketingReport\\'

# Create the .xls workbooK:
wb = xlwt.Workbook()

print(wb)

# add a sheet to the workbook:
wb.add_sheet('first_sheet', cell_overwrite_ok=True)

# we can interact with this sheet with its index value:
# wb.get_active_sheet()

ws_1 = wb.get_sheet(0)


# Can combine both stewps to create and set the active sheet:
ws_2 = wb.add_sheet('second_sheet')


# generate some data intto numpy ndarray:
# 8 x 8 grid containing nums 1 - 64
data = np.arange(1, 65).reshape((8,8))
data

# Use the write method andf provide row, columns with 0 indexing
# writes 100 to the cell A1:
ws_1.write(0, 0, 100)

# get column count:
for c in range(data.shape[0]):
    for r in range(data.shape[1]):
        # Writes row data as columns instead:
        ws_1.write(r, c, int(data[c,r]))
        # Writes rows as rows:
        ws_2.write(r, c, int(data[r,c]))
        
wb.save(path + 'workbook.xls')

# %%
import pyodbc
import pandas as pd
import datetime
from datetime import timedelta


def getTruncDateDash(dt):
    return dt.strftime('%Y-%m-%d')

def getDateKey(dt):
    return int(dt.strftime('%Y%m%d'))

cnxn = pyodbc.connect(r'DRIVER={SQL Server Native Client 11.0};SERVER=ORLEBIPRODDB;DATABASE=INTEGRATION;Trusted_Connection=yes;')
cursor = cnxn.cursor()


now = datetime.datetime.now()
print(str(now))

yesterday = now - timedelta(days=1)
print(str(yesterday))

last_week = now - timedelta(days=7)
print("Last Week: " + str(last_week))

lw_last_month = last_week - timedelta(days=30)
print("Last Week Last Month: " + str(lw_last_month))

date_str = now.strftime('%Y%m%d')

print(date_str)

date_key = int(date_str)

start_date = getTruncDateDash(lw_last_month)
print("Start Date: " + str(start_date))
end_date = getTruncDateDash(last_week)
print("End Date: " + str(end_date))

start_date_sk = getDateKey(lw_last_month)
print("Start Date SK: " + str(start_date_sk))
end_date_sk = getDateKey(last_week)
print("End Date SK: " + str(end_date_sk))

query_str = """
select distinct c.CampaignSentDate, cm.MarketingID, cm.CampaignName, cm.CampignTouchPointName as CampaignTouchPointName, 
ccm.Name as CommunicationType, 
count(*) as TotalNumber
from work.dbo.[TMP_DonorCamp] c
left join INTEGRATION.dbo.Int_dimcampaignmaster_HT cm on cm.CampaignMastersk = c.CampaignMastersk
left join INTEGRATION.dbo.INT_DIMCampaignCommunication ccm on ccm.CommunicationMethodID = c.CommunicationMethodID
where c.campaignsentdate >= '{0}' and c.campaignsentdate < '{1}'
group by c.CampaignSentDate, cm.MarketingID, cm.CampaignName, cm.CampignTouchPointName, ccm.Name
order by 1
""".format(start_date, end_date)
    
    
#columns = [desc[0] for desc in cursor.description]
#print(columns)
#mktJul2018Donors = cursor.fetchall()
    
#for row in mktJul2018Donors:
#    print(row[0], row[3])

    
df = pd.read_sql_query(query_str, cnxn)
df.head()
#writer = pd.ExcelWriter('foo.xlsx')
#df.to_excel(writer, sheet_name='Data')
#writer.save()

# Querying:
#mktJul2018Donors = cursor.fetchall()

#for row in mktJul2018Donors:
#    print(row[0], row[3])


# Output to CSV:
#datafreeze.freeze(mktJul2018Donors, format='csv',
#                  filename='data/mktCollect_Jul18_platelet_dons.csv')

#for row in mktJul2018Donors:
#    print(row['person_id'], row['FullDateUSA'])

# %%
print(df.shape)
print(df.head(100))

writer = pd.ExcelWriter('169_Timeframe_Output_Start_End.xlsx')
# Remove row names (index)
df.to_excel(writer, sheet_name='Summary', index=False)
writer.save()

# %%
from sqlalchemy.orm import sessionmaker
import sqlalchemy as sa
from sqlalchemy import create_engine
from sqlalchemy import (Table, Column, Integer, String, MetaData, ForeignKey, Numeric)
from sqlalchemy import inspect
from sqlalchemy.orm import sessionmaker


metadata = MetaData()

int_engine = sa.create_engine('mssql+pyodbc://ORLEBIDEVDB/Integration?driver=SQL+Server+Native+Client+11.0')
work_engine = sa.create_engine('mssql+pyodbc://ORLEBIDEVDB/WORK?driver=SQL+Server+Native+Client+11.0')
stg_engine = sa.create_engine('mssql+pyodbc://ORLEBIDEVDB/STAGE?driver=SQL+Server+Native+Client+11.0')
# engine = create_engine("mssql+pyodbc://ONEBLOOD\Oswald.Ramirez@MySQLServer")

# db = SQLAlchemy(metadata=metadata)

# persist the schema of the existing database
# metadata.create_all(engine)

# reflect all db schema to MetaData
#metadata.reflect(bind=engine)
metadata.reflect(bind=int_engine)
metadata.reflect(bind=work_engine)
metadata.reflect(bind=stg_engine)

for tablename, tableobj in metadata.tables.items():
    print("{0}".format(tablename))
# Out:
# DimDate
# DimProducts
# Drive_Test_Final
# FIN_CustomerBudgetCopy
# HCLL_BILLING_092016_ppp
# INT_DIMAccountAffiliationMaster
# INT_DIMAccountType
# INT_DIMAntibodyTestTypes
# INT_DIMBloodType
# INT_DIMCampaignCommunication
# Int_dimcampaignmaster
# Int_dimcampaignmaster_22_Aug_2017
# Int_dimcampaignmaster_HT
# INT_DIMCertification
# INT_DIMContractMap
# INT_DIMCustomer
# INT_DIMCustomer_7_Customers
# INT_DIMCustomer_Temp
# INT_DIMCustomer_Test
# INT_DIMCustomer1
# INT_DIMDeferral
# INT_DIMDiscardReason
# Int_DimDonationType
# int_dimDonorSource
# INT_DIMEmployee
# INT_DIMEmployee_Test
# INT_DIMEthnicity
# INT_DIMFailureCode
# INT_DIMInventoryCenter
# INT_DIMLocation
# INT_DIMMachine
# INT_DIMMotivation
# INT_DIMPhysician
# INT_DIMPhysician_test
# INT_DIMProcedureMaster
# INT_DIMProductMaster
# INT_DIMProductMaster_5_06
# INT_DIMProducts
# INT_DIMProducts_back
# INT_DIMReactionMaster
# INT_DIMService
# INT_DIMService_Test
# INT_DIMStagingArea
# INT_DIMTestTypes
# INT_DIMTrTestResultEntryTypes
# INT_DIMVehicles
# INT_FCT_ABOLookup
# INT_FCT_BIO_DLYManufacture
# INT_FCT_BIO_InventoryDetail
# INT_FCT_BIO_InventoryDetailcopy
# INT_FCT_BIO_InventoryLevel
# INT_FCT_BIO_InventoryLeveltest
# INT_FCT_DlyCollection
# INT_FCT_DLYTransReturns
# INT_FCT_EPIDetails
# INT_FCT_FIN_InventoryDetail
# Int_fct_finBudgetDetail
# int_FCT_FINGLPostedAccountDetail
# INT_FCT_HR_OverTime_Back
# INT_FCT_PersonCollection
# INT_FCT_PersonCollection_new
# INT_FCT_PersonDetails
# INT_FCT_PositiveTestResults
# INT_FCT_RSATestResultEPI
# INT_FCT_SummaryEPI
# INT_FCT_SummaryEPI123
# INT_FCTBIOProductParLevel
# INT_FCTBloodTestResult
# INT_FCTBloodTestResult_back
# INT_FCTCollection
# INT_FCTCollection_Back
# INT_FCTLaborHour
# INT_FCTLocationLabor
# INT_FCTOverTime
# INT_FCTOverTime_current
# INT_FCTPlateletDetails
# INT_FCTPlateletDetails_Old
# INT_FCTProductDiscards
# INT_FCTProductDiscardsWithReason
# INT_FCTRecPlasmaDetails
# INT_FCTTestResult
# INT_FCTTransfusion
# INT_FIN_FCT_InventoryDetail
# INT_FIN_FCT_InventoryDetailcopy
# INT_FIN_FCTBloodPurchase
# INT_FIN_FCTBloodPurchase_Back
# INT_FIN_FCTTransfusionRevenueDetail
# INT_FIN_GLAccountMaster
# INT_FIN_GLExpenseDetails
# INT_GLAccountMaster
# INT_HCLL_PatientsTransfused
# INT_HCLL_PhysicianUtilizationDetails
# INT_HR_FCTEmpTurnOver
# INT_HR_FCTOverTime
# INT_HR_FCTOverTime_Old
# INT_LAB_FCTReaction
# INT_MKT_FCTCampaign
# INT_MKT_FCTCampaign_HT
# INT_MKT_FCTCampaign_test
# INT_MKT_FCTCampaignDonationDetail
# INT_MKT_FCTCampaignDonationDetail_HT
# INT_MKT_FCTCampaignDonationDetail_Test
# INT_MKT_FCTCollectionProjection
# INT_MKT_FCTCollectionProjection_Deleted
# INT_MKT_FCTCollectionProjection_Missing
# INT_MKT_FCTDailyGoals
# INT_MKT_FCTDriveShift
# INT_MKT_FCTEmailDetail
# INT_MKT_FCTEmailDetail_HT
# INT_MKT_FCTFutureProjection
# INT_MKT_FCTFutureProjection_Missing
# INT_MKT_FCTShiftNotes
# INT_MKTCollectionDetails
# int_mktfctcampaignappointmentdtl
# INT_MKTFCTCampaignAppointmentDtl_HT
# INT_MKTFCTDonorAppointmentDtl
# INT_Person_Details
# Query
# Staging Area_032317
# STG_eDonHistCampaign
# sysdiagrams
# Table3
# Table4
# Tbale2_FirstTimeDonor
# 6143EBI
# 6143Excel
# ADHOC_127
# All_Def_Loc
# All_Def_Loc_Male
# All_Def_Male
# ccDHQ
# Combined_Male
# CTLMapping
# Data
# DataBase_Dictionary
# Discarded
# HCLL_JUL_2016
# HCLL_PT_JULY_2016
# HCLL_PT_JUNE_2016
# HCLL_PT_JUNE_2016_X
# HCLL_PT_MAY_2016
# HCLLCustomer
# HemaProjections
# INT_MKT_FCTEmailDetail_TEMP
# InventorCenterRegionMap
# Liquid_Plasma
# LocationRegion
# LocationRegion_06262015
# NBCUS_Plasma_Cryoprecipitate
# NBCUS_Plasma_Product
# NBCUS_Plasma_WHOLE_BLOOD
# OBNE
# OT_Detailed
# OT_Summary
# Plasma_Apheresis_Shipment
# Plasma_Discarded
# Procedure_Test_Region
# Product_Manufactured_Test
# SC
# Ship_Ret_Dis
# Ship_Ret_Dis_Territory
# SMART_CAPA
# STG_RSAHSCustomers
# test
# test2
# TMP_DonorCamp
# TMP_DonorCamp_06202016
# TMP_DonorCamp_New
# TMP_DonorCamp_temp_15
# TMP_DonorCamp_test
# TMP_INT_FCT_BIO_InventoryLevel
# TMP_INT_HR_FCT_OT_EmpSup
# 2018_PayDate
# ADHOC_127_Final
# ALLHemaProjections
# Antigen_Test_Results
# BECS_CFDDON
# BECS_DACNTS
# BECS_DCMTRN
# BECS_DNQTRN
# BECS_DNRPRF
# BECS_DNRTST
# BECS_DONDFR
# BECS_DONORS
# BECS_DONORS_PATIENTS
# BECS_DONTRNS
# BECS_INVMAST
# BECS_INVTRN
# BECS_INVTRN_LOOKUP
# BECS_ORDMST
# BECS_ORDRES
# BECS_ORDTST
# BECS_ORDUNT
# BECS_PACNTS
# BECS_PRODSC
# BECS_QSTMST
# BECS_SPCMST
# BECS_STATFL
# Book_table_temp
# CBCSF_SCHEMA_OWNER.CUSTOMER
# CBCSF_SCHEMA_OWNER.CUSTOMERcopy
# EVENT_LOG_INFO
# HCLL_BILLING_092016
# HCLL_BILLING_102016
# InterfaceMapping
# INVTRN_LOOKU_JAX
# IV00101
# JAXInventory20150820
# JSON
# Log
# OLE DB Destination
# PackageExecutionHistory
# People
# registration_dump
# RM00101
# RPT_Customer_Alert
# RPT_ITEMS_Alert
# RSA_DriveCollectionArea
# RSA_RegistrationPersonArchive
# RSA_Vehicles
# RSAPhysicalExam
# RunInfo
# Split Rates example_20150901_20150930
# SSIS_STG_BLDLYFeed
# StatisticsHeader
# STG_BLDLYFeed
# STG_BLDLYFeed1
# STG_BLDLYFeedcopy
# STG_CAPALocation
# STG_CAPALocation_06122017
# STG_CMRS
# STG_CMRS_5_30_2018
# STG_CMRS_old
# STG_CMRS3
# STG_COdabarISBTMap
# STG_CRM_AccountDetails
# STG_CRM_Roles
# STG_EBICollectionLKUP
# STG_EBICollectionLKUP_Tmp
# STG_eDonAppointment
# STG_eDonBloodBankSite
# STG_eDonCampaign
# STG_eDonCampaignTemplates
# STG_eDonCampaignTouchpoints
# STG_eDonDonor
# STG_eDonDonorCampaign
# STG_eDonDonorCampaignHistory
# STG_eDonDonorEmail
# STG_eDonEmail
# STG_eDonOp
# STG_eDonorContacthistory
# STG_eDonTouchpoints
# STG_FinanceLocation
# stg_financelocation_5_15
# STG_FINPayrollPeriod
# STG_FINPayrollPeriod1
# STG_FINPayrollPeriod2
# STG_FINRSALocationXREF
# STG_GP_SOP10202
# STG_GPAccountIndex
# STG_GPActualGLCurrentYear
# STG_GPActualRevenueHistory
# STG_GPBudgetDetails
# STG_GPGL20000
# STG_GPGLAccounts
# STG_GPIV00101
# STG_GPIV00108
# STG_GPIV40400
# STG_GPIV40700
# STG_GPIV40800
# STG_GPOpenYearPosted
# STG_GPOpenYearPosted_20160808
# STG_GPPriceLevel
# STG_GPProduct
# STG_GPProductMap
# STG_GPRM00101
# STG_GPSOP10202
# STG_GPSOP30200
# STG_GPSOP30300
# STG_GPSOPORD
# STG_GPSOPORD_Back
# STG_HCLLBLLCAPDATA
# STG_HCLLCLNTID
# STG_HCLLFCLTYCD
# STG_HCLLFCLTYCTL
# STG_HCLLHL7OBBILLHLD
# STG_HCLLINTPRTN_CD
# STG_HCLLORDMSGMST
# STG_HCLLPFMST
# STG_HCLLPHYSNCD
# STG_HCLLPHYSNSRVCCD
# STG_HCLLPTNTADMSN
# STG_HCLLSRVCCD
# STG_HCLLTSTMST
# STG_HCLLTSTMSTADHOCTST
# STG_HCLLUNIT
# STG_HEMA_ScheduleDetails
# STG_HemaAccountAffiliationDetail
# STG_HemaAccounts
# STG_HemaAccountType
# STG_HEMAActualDash
# STG_HEMAAddressDetail
# STG_HemaAffiliationMaster
# STG_HEMACenterDetail
# STG_HEMACertificationDef
# STG_HEMADonorDetail
# STG_HEMADriveMaster
# STG_HEMADriveShiftActualDetail
# STG_HEMADriveShiftDetail
# STG_HEMADriveShiftProcedureDetail
# STG_HemaEquipmentDetail
# STG_HemaEquipmentMaster
# STG_HEMAGoal
# STG_HEMAInterfaceMapping
# STG_HemaLocation
# STG_HEMAMobileSetupMaster
# STG_HEMAPeople
# STG_HEMAPeopleCenterDetail
# STG_HEMAPeopleCertificationDetail
# STG_HEMAPeopleEmployeeValueDetail
# STG_HEMAPeopleRoleDef
# STG_HEMAPeopleStaffingDetail
# STG_HEMAPeopleStaffingRoleDetail
# STG_HemaProcedure
# STG_HEMARptDriveShiftMobileDetail
# STG_HEMAStaffingEventMaster
# STG_HEMAStaffingEventShiftDetail
# STG_HemaSubCenter
# STG_HEMAZipCodeMaster
# STG_HTAddresses
# STG_HTAppointments
# STG_HTBloodTypes
# STG_HTCampaignElements
# STG_HTCampaigns
# STG_HTCenters
# STG_HTCenterSlots
# STG_HTDirectMailListResults
# STG_HTDirectMailLists
# STG_HTdonations
# STG_HTDonorBecs
# STG_HTDonorPreferencesLog
# STG_HTDonorProspects
# STG_HTDriveMarketing
# STG_HTDriveMarketingResults
# STG_HTDrives
# STG_HTDrivesDriveMarketings
# STG_HTDriveUsers
# STG_HTEmailCollections
# STG_HTEmailLists
# STG_HTEmailOutcomeCodes
# STG_HTEmailQueue
# STG_HTEmailViews
# STG_HTLastDonations
# STG_HTListInstances
# STG_HTLists
# STG_HTListTemplates
# STG_HTPeople
# STG_HTProcedures
# STG_HTSponsors
# STG_HTStaffDrivePeople
# STG_HTStaffUsers
# STG_HTTextMessageLists
# STG_HTTextMessageQueue
# STG_HTVoiceMessageLists
# STG_KRN_ActualDetails
# STG_KRN_HROvertime
# STG_KRNALLPerson
# STG_KRNALLTotals
# STG_KRNCalendarDetails
# STG_KRNCompensationDetails
# STG_KRNEmpTurnOver
# STG_KRNHRTimeSheet
# STG_KRNLaborAccount
# STG_KRNLaborHour
# STG_KRNOrganizationsCurr
# STG_KRNPersonStatusPositionJob
# STG_KRNPunchOrigin
# STG_KRNTimeSheet
# STG_MAKCollectionDetails
# STG_MAKCollectionDetails_old
# STG_MAKCustomers
# STG_MAKPurchaseDetails
# STG_MAKTransfusionDetails
# STG_MAKTransfusionDetails_010815
# STG_MAKTransfusionDetails_010915
# STG_MAKTransfusionDetails_121914
# STG_MAKTransfusionDetails_122314
# STG_MAKTransfusionDetails_old
# STG_MAKTransfusionDetails_old2
# STG_PHYSNSRVCCD
# STG_RSA_DonorDeferral
# STG_RSA_RL_CMVData
# STG_RSA_RL_HemoglobinData
# STG_RSA_TestResult
# STG_RSABagKitFailure
# STG_RSABagKitType
# STG_RSABagKitUsage
# STG_RSABranches
# STG_RSACLDiscardReason
# STG_RSACLFRACSTEPS
# STG_RSACLFRACSTEPTYPES
# STG_RSAClLatestProductStorage
# STG_RSACLPooledCryoMap
# STG_RSACLPoolPlateletMap
# STG_RSACLProcesses
# STG_RSACLProductInventory
# STG_RSACLProductProperties
# STG_RSACLProducts
# STG_RSACLProductStorage
# STG_RSACLQCComments
# STG_RSACLQCproperties
# STG_RSACLQCTestResults
# STG_RSACLRecPlasmaCarton
# STG_RSACLRecPlasmaInventory
# STG_RSACLRecPlasmaShipping
# STG_RSACLStorage
# STG_RSAComplianceComments
# STG_RSADEFERRAL
# STG_RSADeletedDeferral
# STG_RSADistrict
# STG_RSADonation
# STG_RSADonationLabCodes
# STG_RSADonationType
# STG_RSADonorDeferral
# STG_RSADonorGroup
# STG_RSADRAW
# STG_RSADRAW_020415
# STG_RSADRAW_test
# STG_RSADriveCollectionArea
# STG_RSADriveCollectionArea_1
# STG_RSADrives
# STG_RSADrives_1
# STG_RSADSReview
# STG_RSAEMPLOYEE
# STG_RSAEODInventory
# STG_RSAEODInventory_10_17
# STG_RSAEODInventory_10_22
# STG_RSAEODInventory_10_9
# STG_RSAEODInventory_9_18
# STG_RSAEODInventory_9_25
# STG_RSAEthnic
# STG_RSAFAILURECODES
# STG_RSAFINInventory
# STG_RSAFRACSTEPTYPES
# STG_RSAHCLLORDER
# STG_RSAHCLLORDERDETAIL
# STG_RSAHospital
# STG_RSAHSCustomerPriceCodes
# STG_RSAHSIMPORTS
# STG_RSAHSInventory
# STG_RSAHSOrderCancelReason
# STG_RSAHSReturns
# STG_RSAHSShippingMethod
# STG_RSAInventoryCenter
# STG_RSALBCodabarISBTMap
# STG_RSALBLabel
# STG_RSAMachine
# STG_RSAMachine_Old
# STG_RSAMachineLocationMap
# STG_RSAMachineLocBranch
# STG_RSAMAKDonationMap
# STG_RSAMobileStagingArea
# STG_RSAMotivation
# STG_RSAOrderForm
# STG_RSAOrderFormDetails
# STG_RSAOrderMain
# STG_RSAPerson
# STG_RSAPerson_Back
# STG_RSAPerson_CMV
# STG_RSAPerson_HBS
# STG_RSAPerson_HLA
# STG_RSAPerson_Profile_Testing
# STG_RSAPerson1
# STG_RSAPhysicalExam
# STG_RSAPlateletApheresis
# STG_RSAPPChildMap
# STG_RSAPrescription
# STG_RSAPrescriptionRegMap
# STG_RSAProdMgmtComments
# STG_RSAProductFamily
# STG_RSAProductGroups
# STG_RSAPRTKit
# STG_RSAPRTKitProduct
# STG_RSARBCFrozen
# STG_RSARBCFrozen_10_17
# STG_RSARBCFrozen_10_22
# STG_RSARBCFrozen_10_9
# STG_RSARBCFrozen_9_18
# STG_RSARBCFrozen_9_25
# STG_RSARecPLRules
# STG_RSARecPLStatus
# STG_RSARegistration
# STG_RSARegistration_2017
# STG_RSARegistrationPersonArchive
# STG_RSARegStepsCompleted
# STG_RSARLAntibodyResults
# STG_RSARLAntigenAntibodyType
# STG_RSARLAntigenResults
# STG_RSARLAntigenTransaction
# STG_RSARLHemoglobinData
# STG_RSARLResultType
# STG_RSARogueUnits
# STG_RSAShippedInventory
# STG_RSAShippedInventory_After
# STG_RSAShippedInventory_Before
# STG_RSAStagingAreaDistrictMap
# STG_RSATestResult
# STG_RSATestResult_Full
# STG_RSATestResult_HLA
# STG_RSATestTypes
# STG_RSATRABOException
# STG_RSATTMS_SaveSendDiscard
# STG_RSAVehicles
# STG_Safetrace_Returns
# STG_Safetrace_Shipments
# STG_SC_ALL_WORKFLOW_TTD_SS_CAPA
# STG_SC_CAPA_ROOT_CAUSE
# STG_SC_NC
# STG_SC_SS_CAPA
# STG_ST_DNR_DEA
# STG_ST_DNR_DEF
# STG_ST_DNR_DFC
# STG_ST_DNR_DUD
# STG_ST_DNR_VST
# STG_ST_DONORS
# STG_ST_INV_CMS
# STG_ST_INV_REQ
# STG_ST_INV_TSC
# STG_ST_LAB_CMP
# STG_ST_LAB_CMT
# STG_ST_LAB_CSL
# STG_ST_LAB_SPA
# STG_ST_LAB_SPC
# STG_ST_LAB_SPS
# STG_ST_LAB_TSR
# STG_ST_LAB_TST
# STG_ST_NAT_ADR
# STG_ST_NAT_IDN
# STG_ST_NAT_LOC
# STG_ST_NAT_MED
# STG_ST_NAT_MEM
# STG_ST_NAT_NAM
# STG_ST_NAT_PER
# STG_ST_NAT_PHN
# STG_test
# STG_TherapeuticsDetail
# STG_TMP_HTCenterSlots
# STG_TMP_HTEmailQueue
# STG_TMP_HTTextMessageQueue
# STG_UNITNUMBERS
# sysssislog
# t_backup_07022015
# t_STG_RSALBLabel_07022015
# TEMP
# TempEdonorPerson
# TEST
# test_test
# TEST1
# testSRC
# TMPInventorytest
# TST_MST
# Unmatch_UnitNumber
# ZIP

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker,scoped_session


Session = sessionmaker()

# associate it with our custom Session class
Session.configure(bind=work_engine)
# Session.configure(bind=stg_engine) # breaks session

# work with the session
session = Session()

# After reflecting entire db:
mktCollectDtls = metadata.tables['INT_MKTCollectionDetails']
tmp_work = metadata.tables['TMP_DonorCamp']
STG_REG = metadata.tables['STG_RSARegistration']

for col in tmp_work.columns:
    print(col)

print('\n### All tmpwork:')
for tmc in session.query(tmp_work).limit(10):
    print(tmc.Donorexternalkey)
print('')

# %%
"""Example for reflecting database tables to ORM objects

This script creates classes for each table reflected
from the database.

Note: The class names are imported to the global namespace using
the same name as the tables. This is useful for quick utility scripts.
A better solution for production code would be to return a dict
of reflected ORM objects.
"""
import sqlalchemy as sa
from sqlalchemy import create_engine, MetaData
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
import re

def intersect(lst1, lst2):
    return list(set(lst1) & set(lst2))

def reflect_all_tables_to_declarative(uri):
    """Reflects all tables to declaratives

    Given a valid engine URI and declarative_base base class
    reflects all tables and imports them to the global namespace.

    Returns a session object bound to the engine created.
    """

    # create an unbound base our objects will inherit from
    Base = declarative_base()

    engine = sa.create_engine(uri)
    metadata = MetaData(bind=engine)
    Base.metadata = metadata

    g = globals()

    metadata.reflect()
    
    wanted_tables = ['INT_MKTCollectionDetails']

    for tablename, tableobj in metadata.tables.items():
        try:
            if tablename in wanted_tables:
                g[tablename] = type(str(tablename), (Base,), {'__table__' : tableobj })
                print("Reflecting {0}".format(tablename))
        except sa.exc.ArgumentError:
            print("Missing Primary Key: {0}".format(tablename))
            for col in tableobj.c:
                #if re.match(".*sk", str(col), re.I):
                print(col)
                # print(re.match('*SK', col))
            g[tablename] = type(str(tablename), (Base,), 
                                {'__table__' : tableobj,
                                  '__tablename__' : tablename.lower(),
                                 '__mapper_args__' : {
                                        'primary_key': [col for col in tableobj.c if re.match(".*sk", str(col), re.I)]
                                        #PrimaryKeyConstraint(re.match(r'*SK', tablename, re.I))
                                     }
                                })
            #for col in (metadata.tables[tablename]).columns:
            #    print(col)

    Session = sessionmaker(bind=engine)
    return Session()


# Reflect and create declarative orm classes:
session = reflect_all_tables_to_declarative('mssql+pyodbc://ORLEBIDEVDB/Integration?driver=SQL+Server+Native+Client+11.0')
# Out:
# Missing Primary Key: INT_MKTCollectionDetails
# INT_MKTCollectionDetails.CollectionDetailSK
# INT_MKTCollectionDetails.DonationTypeSK
# INT_MKTCollectionDetails.CollectionDateSK
# INT_MKTCollectionDetails.LocationSK
# INT_MKTCollectionDetails.motivationsk
# INT_MKTCollectionDetails.SourceSystem
# INT_MKTCollectionDetails.registrationID
# INT_MKTCollectionDetails.personid
# INT_MKTCollectionDetails.driveid
# INT_MKTCollectionDetails.failurecode
# INT_MKTCollectionDetails.CompletedFlag
# INT_MKTCollectionDetails.UnitNumber
# INT_MKTCollectionDetails.DriveName
# INT_MKTCollectionDetails.createddate
# INT_MKTCollectionDetails.modifieddate
# INT_MKTCollectionDetails.bloodtypesk
# INT_MKTCollectionDetails.discarded
# INT_MKTCollectionDetails.import
# INT_MKTCollectionDetails.EthnicSK
# INT_MKTCollectionDetails.Gender
# INT_MKTCollectionDetails.vehicleUID
# INT_MKTCollectionDetails.vehicleId
# INT_MKTCollectionDetails.MachineID
# INT_MKTCollectionDetails.PrePhlebEmpid
# INT_MKTCollectionDetails.PostPhlebEmpid
# INT_MKTCollectionDetails.RegEmpid
# INT_MKTCollectionDetails.PersonDOB
# INT_MKTCollectionDetails.PersonZipCode
# INT_MKTCollectionDetails.LoadFlag
# INT_MKTCollectionDetails.DHQEmpID
# INT_MKTCollectionDetails.PhyEmpID
# INT_MKTCollectionDetails.ProductCount
# INT_MKTCollectionDetails.StagingAreaSK
# INT_MKTCollectionDetails.MachineSerialNo
# INT_MKTCollectionDetails.TeamLeadEmpID
# INT_MKTCollectionDetails.GroupID
# INT_MKTCollectionDetails.AccountID
# INT_MKTCollectionDetails.AccountInternalName
# INT_MKTCollectionDetails.AccountZipCode
# INT_MKTCollectionDetails.DrawTime
# INT_MKTCollectionDetails.WithdrawlTime
# INT_MKTCollectionDetails.ParentVolume
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-19-691c38f42c87> in reflect_all_tables_to_declarative(uri)
#      44             if tablename in wanted_tables:
# ---> 45                 g[tablename] = type(str(tablename), (Base,), {'__table__' : tableobj })
#      46                 print("Reflecting {0}".format(tablename))
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\ext\declarative\api.py in __init__(cls, classname, bases, dict_)
#      64         if '_decl_class_registry' not in cls.__dict__:
# ---> 65             _as_declarative(cls, classname, cls.__dict__)
#      66         type.__init__(cls, classname, bases, dict_)
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\ext\declarative\base.py in _as_declarative(cls, classname, dict_)
#      87
# ---> 88     _MapperConfig.setup_mapping(cls, classname, dict_)
#      89
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\ext\declarative\base.py in setup_mapping(cls, cls_, classname, dict_)
#     115             cfg_cls = _MapperConfig
# --> 116         cfg_cls(cls_, classname, dict_)
#     117
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\ext\declarative\base.py in __init__(self, cls_, classname, dict_)
#     147
# --> 148         self._early_mapping()
#     149
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\ext\declarative\base.py in _early_mapping(self)
#     150     def _early_mapping(self):
# --> 151         self.map()
#     152
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\ext\declarative\base.py in map(self)
#     575             self.local_table,
# --> 576             **self.mapper_args
#     577         )
#
# <string> in mapper(class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, extension, order_by, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\orm\mapper.py in __init__(self, class_, local_table, properties, primary_key, non_primary, inherits, inherit_condition, inherit_foreign_keys, extension, order_by, always_refresh, version_id_col, version_id_generator, polymorphic_on, _polymorphic_map, polymorphic_identity, concrete, with_polymorphic, polymorphic_load, allow_partial_pks, batch, column_prefix, include_properties, exclude_properties, passive_updates, passive_deletes, confirm_deleted_rows, eager_defaults, legacy_is_orphan, _compiled_cache_size)
#     693             self._configure_polymorphic_setter()
# --> 694             self._configure_pks()
#     695             Mapper._new_mappers = True
#
# c:\users\oswald.ramirez\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\orm\mapper.py in _configure_pks(self)
#    1326                 "key columns for mapped table '%s'" %
# -> 1327                 (self, self.mapped_table.description))
#    1328         elif self.local_table not in self._pks_by_table and \
#
# ArgumentError: Mapper Mapper|INT_MKTCollectionDetails|INT_MKTCollectionDetails could not assemble any primary key columns for mapped table 'INT_MKTCollectionDetails'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-691c38f42c87> in <module>()
#      67
#      68 # Reflect and create declarative orm classes:
# ---> 69 session = reflect_all_tables_to_declarative('mssql+pyodbc://ORLEBIDEVDB/Integration?driver=SQL+Server+Native+Client+11.0')
#
# <ipython-input-19-691c38f42c87> in reflect_all_tables_to_declarative(uri)
#      53             g[tablename] = type(str(tablename), (Base,),
#      54                                 {'__table__' : tableobj,
# ---> 55                                   '__tablename__' : lower(tablename),
#      56                                  '__mapper_args__' : {
#      57                                         'primary_key': [col for col in tableobj.c if re.match(".*sk", str(col), re.I)]
#
# NameError: name 'lower' is not defined

# %%
# mktCollects = Table(g['INT_MKTCollectionDetails'], metadata, autoload=True)
        
mktCollects = session.query(INT_MKTCollectionDetails).filter_by(CollectionDateSK=20180324).all()

for rec in mktCollects:
    print(rec)
# Out:
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C69E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699C6F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EE9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EECF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EED68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699EEF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F80B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F82E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F83C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F84A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F85F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F86D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F87B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F89E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699F8F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FF9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFCF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFD68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C699FFF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A090B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A092E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A093C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A094A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A095F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A096D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A097B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A099E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A09F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A120B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A122E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A123C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A124A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A125F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A126D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A127B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A129E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A12F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1C9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CCF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CD68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A1CF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A240B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A242E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A243C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A244A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A245F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C68ADB320>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69682F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69682EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C68E23198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69688C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69688D30>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69688B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69688A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69688A90>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69688AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C696889E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69688B70>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6965AA90>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6965A908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6965AB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6965A1D0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6962E898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6962E8D0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6962E940>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69636BE0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69636A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6961B710>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6961B4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6961B588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6961B518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C695D0588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C695D0550>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C695FEC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C695FEFD0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C695FEBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C695FEE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A246D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A247B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A249E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A24F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2A9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2ABA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2ACF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AD68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2ADD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2AF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2F9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FCF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FD68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A2FF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A360B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A362E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A363C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A364A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A365F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A366D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A367B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A369E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A36F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3E9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3ECF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3ED68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A3EF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A470B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A472E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A473C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A474A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A475F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A476D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A477B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A479E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A47F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A500B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A502E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A503C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A504A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A505F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A506D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A507B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A509E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A50F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A580B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A582E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A583C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A584A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A585F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A586D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A587B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A589E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A58F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A610B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A612E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A613C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A614A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A615F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A616D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A617B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A619E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A61F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6A9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6ABA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6ACF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AD68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6ADD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A6AF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A730B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A732E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A733C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A734A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A735F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A736D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A737B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A739E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A73F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7D9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DCF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DD68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A7DF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A860B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A862E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A863C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A864A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A865F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A866D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A867B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A869E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A86F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A90048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A900B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A90128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A90198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A90208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A90278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A902E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69A90358>
# ...
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC626D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC627B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC629E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC62F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6C9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CCF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CD68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CF28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC6CF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC750B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC752E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC753C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC754A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC755F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC756D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC757B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC759E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75AC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75EB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75F28>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC75F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E048>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E0B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E2E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E358>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E4A8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E5F8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E748>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7E9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7EA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7EAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7EB38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7EBA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7EC18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7EC88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7ECF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7ED68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6AC7EDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69396080>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6938FFD0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6938FF60>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6938FEF0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6938FE10>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6938FDD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69214630>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69389588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69389438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69389320>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693892B0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69389470>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693893C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6936CF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6936CE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6936CCF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C688D87F0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C68AEE9E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C689D3438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C68A627B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C68950160>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C688F7E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C689DEE10>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C681380F0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937EB00>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937EDA0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937E908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937E7B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937E668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937E518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937E3C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937E278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937E128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6937EE48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C685C59E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C685EE2B0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C68DF53C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693841D0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69384668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69384C88>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69384B38>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69384710>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69384DD8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6849A240>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C68DDABE0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693606A0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693C1D68>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375F98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375A58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693757B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375668>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375518>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693753C8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375128>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375390>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69375400>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693BAA58>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693BA438>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693BA630>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693BA208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693BA6D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693F0278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693E2898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693E2BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693E2EF0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693E27B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693E28D0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693D9630>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693D9278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693D9BE0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693D97F0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693D9860>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693D9198>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693FAB70>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693FA080>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693FA278>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69402978>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69402710>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693CCCC0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693CC080>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693CC208>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C693CCAC8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6941AEB8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6941A240>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6941A320>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6941A400>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C694376D8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69437080>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69411C18>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C694110B8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69411BA8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69411550>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C694542E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C694541D0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69454550>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69366940>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69366898>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69366828>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C694911D0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69491FD0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6945ACC0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6945ACF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69486908>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69486E48>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69486EF0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C694249B0>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69424CF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69424B70>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C694249E8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69424D30>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C69424940>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6946FF98>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6946FCF8>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6946F588>
# <__main__.INT_MKTCollectionDetails object at 0x0000025C6942F3C8>

# %%
import sqlalchemy as sa
from sqlalchemy import create_engine
from sqlalchemy import (Table, Column, Integer, String, MetaData, ForeignKey, Numeric)
from sqlalchemy import inspect
from sqlalchemy.orm import sessionmaker


metadata = MetaData()

engine = sa.create_engine('mssql+pyodbc://ORLEBIDEVDB/Integration?driver=SQL+Server+Native+Client+11.0')


# db = SQLAlchemy(metadata=metadata)

# persist the schema of the existing database
# metadata.create_all(engine)
# print(metadata.tables)

# reflect all db schema to MetaData
metadata.reflect(bind=engine)
#print(metadata.tables.keys())

# %%
# Reflect an individual tables:
# mktCollectDtls = Table('INT_MKTCollectionDetails', metadata, autoload=True, autoload_with=engine)

#for col in mktCollectDtls.columns:
    #print(col)
    
metadata.tables['TMP_DonorCamp']

# Loses foreign keys when we reflect an individual table at a time:
# mktCollectDtls.foreign_keys

# %%
from sqlalchemy import select

# After reflecting entire db:
mktCollectDtls = metadata.tables['INT_MKTCollectionDetails']

for col in mktCollectDtls.columns:
    print(col)

# Keeps foreign keys when we reflect entire db:
# mktCollectDtls.foreign_keys

# rUN QUERY AGAINST tABLE OBJECT:
#s = select([mktCollectDtls]).limit(10)
#engine.execute(s).fetchall()

# %%
from sqlalchemy.orm import sessionmaker

# create a Session
Session = sessionmaker(bind=engine)
session = Session()

# After reflecting entire db:
mktCollectDtls = metadata.tables['INT_MKTCollectionDetails']

# s = select([mktCollectDtls.c.personid, mktCollect.c.CollectionDateSK])
# s = s.order_by(mktCollectDtls.c.personid)
# s = s.limit(10)

# Create objects  
for mktCollect in session.query(mktCollectDtls).order_by(mktCollectDtls.c.personid).limit(10):
    print (mktCollect.personid, mktCollect.CollectionDateSK)
