# %%
import sqlalchemy as sa
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect

import pandas as pd

engine = sa.create_engine('mssql+pyodbc://ORLEBIDEVDB/INTEGRATION?driver=SQL+Server+Native+Client+11.0')

# Create df from data:
df = pd.read_sql('SELECT TOP 10 * FROM INT_MKTCollectionDetails', engine)

# %%
df.head()
# Out:
#    CollectionDetailSK  DonationTypeSK  CollectionDateSK  LocationSK  \
# 0             3439560               1          20180604         125
# 1             3439561               1          20180604          10
# 2             3439562               1          20180604         122
# 3             3439563               1          20180604         105
# 4             3439564               1          20180604         134
#
#    motivationsk SourceSystem  registrationID  personid    driveid failurecode  \
# 0             2          RSA       108451707  53021103  2170872.0        None
# 1             2          RSA       108451442  53388315        NaN        None
# 2             2          RSA       108450953  54721039  2158112.0        None
# 3             2          RSA       108451468  53350533  2119382.0        None
# 4             2          RSA       108452219  55045414  2158271.0        None
#
#       ...      StagingAreaSK MachineSerialNo TeamLeadEmpID  GroupID AccountID  \
# ...

# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient()
# Get DB regsJul18
db = client.regsJul18
# Find all Documents in the collection plDonorsJul18
cursor = db.plDonorsJul18.find()

df = pd.DataFrame(list(cursor))

df.head()
# Out:
#   FullDateUSA                       _id  min_reg_id  person_id  \
# 0  07/10/2018  5b81c449cb27571e16b36296   108554861   51823783
# 1  07/10/2018  5b81c449cb27571e16b36297   108555071   51870243
# 2  07/10/2018  5b81c449cb27571e16b36298   108555499   51874655
# 3  07/10/2018  5b81c449cb27571e16b36299   108554767   51889397
# 4  07/10/2018  5b81c449cb27571e16b3629a   108554570   51923905
#
#    total_platelet_donations
# 0                         1
# 1                         1
# 2                         1
# 3                         2
# 4                         2
